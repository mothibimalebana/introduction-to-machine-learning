# %%
import pandas as pd
import numpy as np

data = pd.read_csv('titanic3.csv')

# %%
x = np.array([[1,2,3], [4,5,6]])
print(f"x:\n {x}")
# Out:
# x:
#  [[1 2 3]
#  [4 5 6]]

# %%
from scipy import sparse

eye = np.eye(4)
print(f"NumPy array:\n {eye}")
